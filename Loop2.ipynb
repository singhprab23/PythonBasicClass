# %% [markdown]
# <a href="https://colab.research.google.com/github/singhprab23/PythonBasicClass/blob/main/Loop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q. Write a loop to print the numbers - 1, 4, 7, 10, 13, 16 in the same line

i=1

for i in range(1,17,3):
  if i==16:
    print(i,end="")
  else:
    print(i,end=", ")
# Out:
# 1, 4, 7, 10, 13, 16

# %%
i=1

for i in range(1,17,3):
  if i==16:
    pass
  else:
    print(i,end=", ")

# %%
for i in range(5):
  if i==3:
    pass # does notion is a place holder
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
  if i==3:
    continue # Skip the iteration
  print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
for i in range(5):
  if i==3:
    break # break the iteration
  print(i)
# Out:
# 0
# 1
# 2

# %%
x = 0
while x < 5:
    x += 1
    print("Increment:",x)
    if x == 3:
      print("i was here but no logic")
      continue

    print("Final Print:",x)
# Out:
# Increment: 1
# Final Print: 1
# Increment: 2
# Final Print: 2
# Increment: 3
# i was here but no logic
# Increment: 4
# Final Print: 4
# Increment: 5
# Final Print: 5

# %%
x = 0
while x < 5:
    x += 1
    if x == 3:
        break
    print(x)
print("Loop finished")
# Out:
# will not come at i==3 1
# will not come at i==3 2
# Loop finished

# %%
x = 0
while x < 5:
    x += 1
    if x == 3:
        continue
    print(x)
print("Loop finished")
# Out:
# 1
# 2
# 4
# 5
# Loop finished

# %%
x = 0
while True:
    x += 1
    if x == 3:
        break
    print(x)
print("Loop finished")
# Out:
# 1
# 2
# Loop finished

# %%
count = 0
while True:
    if count == 5:
        break
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(3):
  for j in range(3):
    print("*",end=" ");
# Out:
# * * * * * * * * *

# %%
for i in range(3):
  for j in range(3):
    print("*",end=" ");
  print()
# Out:
# * * *
# * * *
# * * *

# %%
for i in range(3):
  for j in range(3):
    print(j,end=" ");
  print()
# Out:
# 0 1 2
# 0 1 2
# 0 1 2

# %%
for i in range(3):
  for j in range(i,3):
    print(j,end=" ");
  print()
# Out:
# 0 1 2
# 1 2
# 2

# %%
for i in range(3):
    for j in range(i, 3):
        print("*", end=" ")
    print()
# Out:
# * * *
# * *
# *
