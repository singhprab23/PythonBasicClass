# %% [markdown]
# <a href="https://colab.research.google.com/github/singhprab23/PythonBasicClass/blob/main/Python_Class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(2+3)
# Out:
# 5
